# %% [markdown]
# ![alt text](https://github.com/acmarpu/images/blob/main/Python/09_dict_type.png)
#
# - [Dictionary Data Type](#-dictionary-data-type)
#    - [Creating ictonary](#2-creating-dictonary)
#    - [Accessing value](#3-accessing-value-from-dictionary)
#    - [Change or add values](#4-change-or-add-values)
#    - [Delete or Remove](#5-delete-or-remove-values)
#    - [Copy](#6-copy-shallow-copy)
#    - [pop](#10-pop)

# %% [markdown]
# --------------------------------------------------------------------------------------------------
# ### 🔑 Dictionary Data Type
# --------------------------------------------------------------------------------------------------
# #### 1. what is dictionary :
# * A **dictionary** is an **unordered collection of key-value pairs**.
# * It stores elements in **pairs**, where each key is associated with a value. - Each key-value pair is called an **item**: `{key: value}`
#
# 📌 **Key Points:**
#
#    * **Ordered Collection:** As of Python 3.7+, dictionaries maintain the order of insertion, meaning the order in which you add key-value pairs is preserved.
#    * **Keys are Immutable:** The keys must be of immutable types (e.g., strings, numbers, tuples). You cannot use mutable types (like lists) as keys.
#    * **Unique Keys:** Dictionary keys must be unique. If you try to insert a duplicate key, it will update the existing key with the new value.
#    * **Mutable Values:** Values can be of any data type, and they do not need to be unique.
#    * **Creation:** You can create a dictionary using curly braces {} or by using the dict() constructor.
#    * *Creating a Dictionary:*
#    * **Empty dictionary:** Use {} or dict().
#    * **Non-empty dictionary:** Use curly braces {} with key-value pairs separated by a colon (:).

# %% [markdown]
# #### 2. creating dictonary

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
print("Output of Dictionary:", dict)
# Out:
# Output of Dictionary: {'code': 'python', 'server': 'vm', 'cloud': 'azure'}

# %% [markdown]
# #### 3. accessing value from dictionary

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
print("Output of single key value:" , dict["code"])
# print("Output of single key value:" , dict["age"])

# %% [markdown]
# #### 4. Change or add values

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
print("Output of Dictionary:", dict)

# Change
dict["cloud"] = "aws"
print("Output of Dictionary after change the key value:", dict)

# add
dict["data"] = "raw_data"
print("Output of Dictionary after adding the key value:", dict)
# Out:
# Output of Dictionary: {'code': 'python', 'server': 'vm', 'cloud': 'azure'}
# Output of Dictionary after change the key value: {'code': 'python', 'server': 'vm', 'cloud': 'aws'}
# Output of Dictionary after adding the key value: {'code': 'python', 'server': 'vm', 'cloud': 'aws', 'data': 'raw_data'}

# %% [markdown]
# #### 5. delete or remove values

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
del dict["server"]
print("Output of Dictionary after delete the key value:", dict)
# Out:
# Output of Dictionary after delete the key value: {'code': 'python', 'cloud': 'azure'}

# %% [markdown]
# #### 6. copy (Shallow Copy)

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
print("Output of Dictionary:", dict)

dict1 = dict

print("Output of assigan value to dict1:", dict)


dict["server"] = "system"

print("Output of Dictionary:", dict)
print("Output of dict1:", dict)
# Out:
# Output of Dictionary: {'code': 'python', 'server': 'vm', 'cloud': 'azure'}
# Output of assigan value to dict1: {'code': 'python', 'server': 'vm', 'cloud': 'azure'}
# Output of Dictionary: {'code': 'python', 'server': 'system', 'cloud': 'azure'}
# Output of dict1: {'code': 'python', 'server': 'system', 'cloud': 'azure'}

# %% [markdown]
# #### 7. items and keys and values
# * The `keys()` method returns **all the keys** in a dictionary.

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }

print(dict.items())

# The `keys()` method returns **all the keys** in a dictionary.
print("output of keys:", dict.keys())

print("output of values:", dict.values())
# Out:
# dict_items([('code', 'python'), ('server', 'vm'), ('cloud', 'azure')])
# output of keys: dict_keys(['code', 'server', 'cloud'])
# output of values: dict_values(['python', 'vm', 'azure'])

# %% [markdown]
# #### 8. membership test
# * Membership test applies only to keys.

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }

print(123 in dict)

print("server" in dict)
# Out:
# False
# True

# %% [markdown]
# 9. len

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
print(len(dict))
# Out:
# 3

# %% [markdown]
# #### 10. pop

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
value = dict.pop("server")
print(value)
# Out:
# vm

# %% [markdown]
# #### 11.popitem

# %%
dict = {"code":"python", "server":"vm", "cloud": "azure" }
dict.popitem()
print(dict)
# Out:
# {'code': 'python', 'server': 'vm'}

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ##### Dictionary Data Type Completed
#
# 📖 **Next Topic:**
# 👉 [Range Data Type](10_range_data_type.ipynb)
# ----------------------------------------------------------------------------------------------
